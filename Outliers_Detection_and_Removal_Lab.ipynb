# %% [markdown]
# This session introduces key notions in data cleaning.
#
# <h1><center>Basics of data cleaning for CSCI 412/612: outliers</center></h1>
#
# At this stage, you are able to reformat raw data into a proper spreadsheet and run a classification algorithm on it. Unfortunately, there is a _lot_ more to be done on data pre-processing. By considering that all data is equally valuable and giving it all to the algorithm, we also pass on a lot of trash. And as the saying goes, "garbage in, garbage out".
#
# If we build a model on bad data, we get a bad model. So let's start dealing with what can make data 'bad'. The <font color='red'>focus of this lab is on outliers</font>. Specifically, the objectives are to:
# 1. Detect the __presence of outliers__, and
# 2. __Handle the outliers__.
#
# The <font color='blue'>dataset is downloaded using the first cell of code. If you mess up the data when writing your own code, simply re-run the topmost cell and it will reset your data!</font>
#
# <img src="https://cdn-images-1.medium.com/max/1200/1*yWFQiGjlgHUVYeh4ELELyw.jpeg">
#
# * Useful references:
# * https://machinelearningmastery.com/robust-scaler-transforms-for-machine-learning/
# * https://machinelearningmastery.com/how-to-use-statistics-to-identify-outliers-in-data/

# %% [markdown]
# # 1. A classic but rigid definition of outliers
#
# An outlier is a data point that significantly 'differs' from others. In other words, an outlier is a point that may not be very representative of the overall distribution. <b>Applying machine learning on data that has outliers may produce poor results</b>, because the outliers will have a disproportionate impact. That is, a machine learning method may be significantly biased by the presence of a few outliers, and thus produce results that will not generalize well.
#
# The code below will open data that has outliers. You will use this <b>dataset</b> throughout the lab. If you mess it up, simply re-run the cell below and it'll load up it fresh again.

# %%
#imports and inline command
#Brian Conway
#Assisted by Agustine Lopez
import pandas as pd
from pandas import DataFrame
import matplotlib.pyplot as plt
# %matplotlib inline

#the data is hosted online, so we specify the URL
dataURL="https://archive.ics.uci.edu/ml/machine-learning-databases/undocumented/connectionist-bench/sonar/sonar.all-data"
#we open the dataset noting that there is no header line.
#In the absence of a header, columns are automatically numbered, starting at 0
#Rather than just having numbers, we add a prefix V, making them V0, V1, ... for vendetta (that is a joke)
dataset=pd.read_csv(dataURL,header=None,prefix="V")
dataset.head()
# Out:
#        V0      V1      V2      V3      V4      V5      V6      V7      V8  \
# 0  0.0200  0.0371  0.0428  0.0207  0.0954  0.0986  0.1539  0.1601  0.3109
# 1  0.0453  0.0523  0.0843  0.0689  0.1183  0.2583  0.2156  0.3481  0.3337
# 2  0.0262  0.0582  0.1099  0.1083  0.0974  0.2280  0.2431  0.3771  0.5598
# 3  0.0100  0.0171  0.0623  0.0205  0.0205  0.0368  0.1098  0.1276  0.0598
# 4  0.0762  0.0666  0.0481  0.0394  0.0590  0.0649  0.1209  0.2467  0.3564
#
#        V9  ...     V51     V52     V53     V54     V55     V56     V57  \
# 0  0.2111  ...  0.0027  0.0065  0.0159  0.0072  0.0167  0.0180  0.0084
# 1  0.2872  ...  0.0084  0.0089  0.0048  0.0094  0.0191  0.0140  0.0049
# 2  0.6194  ...  0.0232  0.0166  0.0095  0.0180  0.0244  0.0316  0.0164
# 3  0.1264  ...  0.0121  0.0036  0.0150  0.0085  0.0073  0.0050  0.0044
# 4  0.4459  ...  0.0031  0.0054  0.0105  0.0110  0.0015  0.0072  0.0048
#
#       V58     V59  V60
# 0  0.0090  0.0032    R
# 1  0.0052  0.0044    R
# 2  0.0095  0.0078    R
# 3  0.0040  0.0117    R
# 4  0.0107  0.0094    R
#
# [5 rows x 61 columns]

# %% [markdown]
# ## 1.1 Graphical approach: visually inspecting distributions
# When we get new data, sometimes we have no idea what's inside. Visualizing it isn't a proof, so it's not particularly rigorous, but it gives a 'sense' of what statistics we may actually need to apply. We may get a first intuitive feeling for the presence of outliers when noticing that:
# 1. the bulk of the data falls in a narrow region, with very few points are far from this. That is, we have a long tailed distribution.
# 2. there are gaps in the tail of the distribution, with a few points "out there" on their own.
#
# An example that matches these two criteria is shown in the picture below, where the point on the left is an outlier:
# <img src="http://mathworld.wolfram.com/images/eps-gif/OutlierHistogram_1000.gif">

# %% [markdown]
# > ___Milestone 1___
# >
# > Write a script that loops through the columns of your data and outputs <b>one histogram for each distribution</b> so you can visualize them. You can limit yourself to looping through 10-20 of them: you _do not_ need to look at all 60 features! To plot with Pandas, [check this link!](https://pandas.pydata.org/pandas-docs/stable/user_guide/visualization.html#visualization-hist)
# >
# > Please <b>avoid displaying several histograms on the same space</b> (i.e. on top of each other). That gets very confusing quickly, so after 3 overlays you just cannot see anything anymore.
# >
# > Visually inspect the output of your script, and note which columns look like they may have outliers. Finally, in a Markdown-formatted table, <font color='blue'><b>list the 3 features that most clearly exhibit the presence of outliers in your eyes.</b></font> You're only looking for the top three 'most striking outliers', so you don't need to list every single one.

# %% [markdown]
# ---
# ---
# _Your beautiful code will be written in the cell below._

# %%
#Prof only wants 3 at a time displayed so make a list of 3 columns, loop through it, then repeat 3 times
#this will get 12 histograms displayed when we're limiting ourselves to 10-20

#This 3 column changes each cell
threeCol=['V0','V1','V2']

#counter for while loop
i=0
while(i<3):
    #Plotting the column on a histogram
    df1 = pd.DataFrame(dataset, columns=[threeCol[i]])
    df1.plot.hist()
    i=i+1

# %%
#lather rinse repeat
threeCol=['V3','V4','V5']

i=0
while(i<3):
    df1 = pd.DataFrame(dataset, columns=[threeCol[i]])
    df1.plot.hist()
    i=i+1

# %%
#Lather rinse repeat 
threeCol=['V6','V7','V8']

i=0
while(i<3):
    df1 = pd.DataFrame(dataset, columns=[threeCol[i]])
    df1.plot.hist()
    i=i+1

# %%
#Rinse, lather repeat, or something like that. Instructions unclear made a sandwhich instead.
threeCol=['V10','V11','V12']

i=0
while(i<3):
    df1 = pd.DataFrame(dataset, columns=[threeCol[i]])
    df1.plot.hist()
    i=i+1

# %% [markdown]
# > ___<font color='grey'>(Optional)</font> Milestone 1: Stretch Goal___
# >
# > Plotting dozens of histogram is a simple way to see what it's in the data, but it's a bit <i>primitive</i> and overwhelming. We have developed much more informative approaches. Dumping all these histograms is like using an axe to chop trees: it works, but everyone else uses chainsaws and will think that you belong to a different century with your axe. A professional data scientist would normally use more compact information visualizations: at the very least a <b>boxplot</b> (out of laziness...) or preferentially a <b>violin plot</b>. A boxplot can summarize key features of a histogram using a single column, so you can pack a lot of information in the same space (instead of one histogram after one histogram).
# >
# > [This link](https://matplotlib.org/gallery/statistics/boxplot_demo.html#sphx-glr-gallery-statistics-boxplot-demo-py) shows you how to use boxplots. Look closely at the second figure which has ten boxplots: that summarizes the information that you would otherwise display in ten consecutive histograms!
# >
# > The issue with a boxplot is that a lot of information is lost. We can se quartiles, median and outliers... but we have no idea what's the shape of the distribution. So it's not perfectly equivalent to seeing a histogram, which gives us the shape. A violin plot handles that problem: instead of showing every distribution as a 'box' (in a boxplot), it uses curves to hint as to the data distribution. [This link](https://seaborn.pydata.org/generated/seaborn.violinplot.html) shows you how to use violin plots like a pro :)
# >
# > Our course is on machine learning rather than on data visualization. So you're encouraged to develop professional skills with boxplots and violin plots, but that's not a learning outcome of the course. Hence you're not going to be tested on displaying these visualizations.
#
# ---
# ---
# _Your wonderful but optional code may be written in the cell below._

# %%
import seaborn as sns #has a 1-line boxplot library

sns.boxplot(data=dataset)#haven't loaded data into a frame yet so dataset not variable name for df
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## 1.2 Statistical approach: deviating from quartiles
#
# Visualizations can be very efficient for communication (e.g., to 'show' that there are outliers) but they can be problematic to automatically process large amounts of data. It's tedious to look at a few distributions, and it's also inconsistent when you make decisions based on what you look at. It's also neither scalable nor automatic, as you have to look, and you can't do it for even dozens of features. Bottom line: we need statistical solutions as they'll lead to automatic, scalable ways to detect outliers.
#
# The simplest such solution consists of doing the following to each feature/column:
# 1. Compute the quartiles. This tells you the value for 25% (lower quartile), 50%, and 75% (upper quartile) of the data.
# 2. Compute the inter-quartile range (IQR), that is, the difference between upper and lower quartiles.
# 3. An outlier is a data point more than <b>1.5</b> IQRs below the lower quartile or above the upper quartile.
#
# Here is an example. Feature V0 has a lower quartile of 0.013350, and an upper quartile of 0.035550. This leads to $IQR = 0.035550 - 0.013350 = 0.0222$. That means that a data point is an outlier if it's less than $0.013350 - 1.5*0.0222 = -0.01995$, or more than $0.035550 + 1.5*0.0222 = 0.06885$. In this case, the point 0.137100 would be flagged as outlier.
#
# > ___Milestone 2___
# >
# > For each column, compute the quartiles and then the IQR. Count how many values in this column qualify as outliers. By repeating your calculation across each column, provide the <font color='blue'>% of values that qualify as outliers.</font>
# >
# > _Hint: To get the quartiles, you can ask Pandas to statistically describe the data via dataset.describe(), and that produces a new data frame (so it's easy to loop through)._
#
# ---
# ---
# Fantastic code starts below!

# %%
#Gonna limit it to the first 12 columns so that this doesn't take hours to run
df=pd.DataFrame(dataset, columns=['V0','V1','V2','V3','V4','V5','V6','V7','V8','V9','V10','V11','V12'])
df1=df.describe()
df1
# Out:
#                V0          V1          V2          V3          V4          V5  \
# count  208.000000  208.000000  208.000000  208.000000  208.000000  208.000000
# mean     0.029164    0.038437    0.043832    0.053892    0.075202    0.104570
# std      0.022991    0.032960    0.038428    0.046528    0.055552    0.059105
# min      0.001500    0.000600    0.001500    0.005800    0.006700    0.010200
# 25%      0.013350    0.016450    0.018950    0.024375    0.038050    0.067025
# 50%      0.022800    0.030800    0.034300    0.044050    0.062500    0.092150
# 75%      0.035550    0.047950    0.057950    0.064500    0.100275    0.134125
# max      0.137100    0.233900    0.305900    0.426400    0.401000    0.382300
#
#                V6          V7          V8          V9         V10         V11  \
# count  208.000000  208.000000  208.000000  208.000000  208.000000  208.000000
# mean     0.121747    0.134799    0.178003    0.208259    0.236013    0.250221
# std      0.061788    0.085152    0.118387    0.134416    0.132705    0.140072
# min      0.003300    0.005500    0.007500    0.011300    0.028900    0.023600
# 25%      0.080900    0.080425    0.097025    0.111275    0.129250    0.133475
# 50%      0.106950    0.112100    0.152250    0.182400    0.224800    0.249050
# 75%      0.154000    0.169600    0.233425    0.268700    0.301650    0.331250
# max      0.372900    0.459000    0.682800    0.710600    0.734200    0.706000
#
#               V12
# count  208.000000
# mean     0.273305
# std      0.140962
# min      0.018400
# 25%      0.166125
# 50%      0.263950
# 75%      0.351250
# max      0.713100

# %%
#Need to use fd.iloc to access the 25%, 50%, and 75% rows because it'll read the names of those as numbers

#another counter for another while loop
i=0
#names of columns
columns=['V0','V1','V2','V3','V4','V5','V6','V7','V8','V9','V10','V11','V12']

#plots the outliers on 
while(i<12):
    #translates to 75%-25%, aka IQR
    IQR=df1.iloc[6,i]-df1.iloc[4,i]
    #25%-1.5*IQR per formula
    min_lim= df1.iloc[4,i] - 1.5 * IQR 
    #75%-1.5*IQR per formula
    max_lim= df1.iloc[6,i] + 1.5 * IQR 
    outlier =[] 
    for x in df[columns[i]]:
        if (x> max_lim) or (x<min_lim):
            outlier.append(x) 
    percentageOut=(len(outlier)/208)*100
    print('outlier percentage on column', i+1,':')
    print(percentageOut)
    outlier.clear()
    i=i+1
# Out:
# outlier percentage on column 1 :
# 7.211538461538461
# outlier percentage on column 2 :
# 6.25
# outlier percentage on column 3 :
# 5.288461538461538
# outlier percentage on column 4 :
# 6.25
# outlier percentage on column 5 :
# 2.403846153846154
# outlier percentage on column 6 :
# 3.8461538461538463
# outlier percentage on column 7 :
# 2.403846153846154
# outlier percentage on column 8 :
# 5.288461538461538
# outlier percentage on column 9 :
# 3.8461538461538463
# outlier percentage on column 10 :
# 4.807692307692308
# outlier percentage on column 11 :
# 2.403846153846154
# outlier percentage on column 12 :
# 0.9615384615384616

# %% [markdown]
# # In the second task, you computed the % of all values that are outliers. It's important to understand how it affects the rows/samples/entries. What you eventually feed to a machine learning algorithm is a set of rows (themselves consisting of values). If most rows are affected by outliers, then it means there is garbage throughout your dataset, and it lowers the confidence you can have in your results. Alternatively, if only a few rows are affected by outliers, then you may simply remove them and focus on a sufficient large sample of good quality data.
#
# __We'll create a visualization showing how the rows are affected by outliers__. The $y$-axis is the percentage of rows. The $x$-axis states that this % of rows has exactly $x$ outlier values (i.e. there are $x$ columns on which this % of rows has outliers). For example, $y$=50 and $x$=2 would say that half of your data has 2 outliers. Similarly, $y$=20 and $x$=10 states that 20% of your data has 10 outliers. Here is a sketch:
# <img src="sketch.png">
#
# > ___Milestone 3___
# >
# > <font color='blue'>Write the code to create this figure based on your data.</font>
# >
# > _Hint: loop over the number of missing values $x$ and compute what percentage $y$ it affects. You can store this data in a data series, and then [plot it as bar graph](https://pandas.pydata.org/pandas-docs/stable/user_guide/visualization.html#visualization-barplot)._
#
# Beautiful code starts here.
#
# ---
# ---

# %%
#creating a copy of a dataset we can change values on
dataset_no_outliers = dataset.copy(deep=True)
dataset_no_outliers
# Out:
#          V0      V1      V2      V3      V4      V5      V6      V7      V8  \
# 0    0.0200  0.0371  0.0428  0.0207  0.0954  0.0986  0.1539  0.1601  0.3109
# 1    0.0453  0.0523  0.0843  0.0689  0.1183  0.2583  0.2156  0.3481  0.3337
# 2    0.0262  0.0582  0.1099  0.1083  0.0974  0.2280  0.2431  0.3771  0.5598
# 3    0.0100  0.0171  0.0623  0.0205  0.0205  0.0368  0.1098  0.1276  0.0598
# 4    0.0762  0.0666  0.0481  0.0394  0.0590  0.0649  0.1209  0.2467  0.3564
# ..      ...     ...     ...     ...     ...     ...     ...     ...     ...
# 203  0.0187  0.0346  0.0168  0.0177  0.0393  0.1630  0.2028  0.1694  0.2328
# 204  0.0323  0.0101  0.0298  0.0564  0.0760  0.0958  0.0990  0.1018  0.1030
# 205  0.0522  0.0437  0.0180  0.0292  0.0351  0.1171  0.1257  0.1178  0.1258
# 206  0.0303  0.0353  0.0490  0.0608  0.0167  0.1354  0.1465  0.1123  0.1945
# 207  0.0260  0.0363  0.0136  0.0272  0.0214  0.0338  0.0655  0.1400  0.1843
#
#          V9  ...     V51     V52     V53     V54     V55     V56     V57  \
# 0    0.2111  ...  0.0027  0.0065  0.0159  0.0072  0.0167  0.0180  0.0084
# 1    0.2872  ...  0.0084  0.0089  0.0048  0.0094  0.0191  0.0140  0.0049
# 2    0.6194  ...  0.0232  0.0166  0.0095  0.0180  0.0244  0.0316  0.0164
# 3    0.1264  ...  0.0121  0.0036  0.0150  0.0085  0.0073  0.0050  0.0044
# 4    0.4459  ...  0.0031  0.0054  0.0105  0.0110  0.0015  0.0072  0.0048
# ..      ...  ...     ...     ...     ...     ...     ...     ...     ...
# 203  0.2684  ...  0.0116  0.0098  0.0199  0.0033  0.0101  0.0065  0.0115
# 204  0.2154  ...  0.0061  0.0093  0.0135  0.0063  0.0063  0.0034  0.0032
# 205  0.2529  ...  0.0160  0.0029  0.0051  0.0062  0.0089  0.0140  0.0138
# 206  0.2354  ...  0.0086  0.0046  0.0126  0.0036  0.0035  0.0034  0.0079
# 207  0.2354  ...  0.0146  0.0129  0.0047  0.0039  0.0061  0.0040  0.0036
#
#         V58     V59  V60
# 0    0.0090  0.0032    R
# 1    0.0052  0.0044    R
# 2    0.0095  0.0078    R
# 3    0.0040  0.0117    R
# 4    0.0107  0.0094    R
# ..      ...     ...  ...
# 203  0.0193  0.0157    M
# 204  0.0062  0.0067    M
# 205  0.0077  0.0031    M
# 206  0.0036  0.0048    M
# 207  0.0061  0.0115    M
#
# [208 rows x 61 columns]

# %%
#Replace all the outliers with NaN
stats = dataset.describe()

#Store the pandas description of the dataset for ease of access
stats_no_outliers = dataset_no_outliers.describe()

#Calculating everything again cuz we need to do something different with it this time
#This time saving it as variables outside of a loop
#For each features in the discrption of the dataset
for this_feature in stats:
  #Calculate the lower quartile and store it
  Low_Quart = stats[this_feature]['25%']
  #Calculate the highest quartile and store it
  High_Quart = stats[this_feature]['75%']

  #Calculate the Inter-Quartile range for this column
  this_IQR = High_Quart - Low_Quart
  #Calculate the minumum and maximum value a value has to pass to be considered an outlier
  Less_For_Out = Low_Quart - 1.5 * this_IQR
  More_For_Out = High_Quart + 1.5 * this_IQR

  #For each value in this column

  # for this_value in dataset_no_outliers[this_feature]:
  for index, this_value in dataset[this_feature].iteritems():
    
    #Check if a value in the column is an outlier
    #I am also replacing outlier values with NaN
    if(this_value < Less_For_Out or this_value > More_For_Out):
      # print("The less is: ", Less_For_Out, " And the More For is:", More_For_Out)
      print("This_Value is for original dataset is: ", this_value)
      print("The value at the other dataset index and feature is: ", dataset_no_outliers.at[index, this_feature])
      dataset_no_outliers.at[index, this_feature] = None
# Out:
# This_Value is for original dataset is:  0.0762
# The value at the other dataset index and feature is:  0.0762
# This_Value is for original dataset is:  0.0856
# The value at the other dataset index and feature is:  0.0856
# This_Value is for original dataset is:  0.1313
# The value at the other dataset index and feature is:  0.1313
# This_Value is for original dataset is:  0.0715
# The value at the other dataset index and feature is:  0.0715
# This_Value is for original dataset is:  0.1371
# The value at the other dataset index and feature is:  0.1371
# This_Value is for original dataset is:  0.115
# The value at the other dataset index and feature is:  0.115
# This_Value is for original dataset is:  0.0968
# The value at the other dataset index and feature is:  0.0968
# This_Value is for original dataset is:  0.079
# The value at the other dataset index and feature is:  0.079
# This_Value is for original dataset is:  0.1083
# The value at the other dataset index and feature is:  0.1083
# This_Value is for original dataset is:  0.1088
# The value at the other dataset index and feature is:  0.1088
# This_Value is for original dataset is:  0.0731
# The value at the other dataset index and feature is:  0.0731
# This_Value is for original dataset is:  0.0707
# The value at the other dataset index and feature is:  0.0707
# This_Value is for original dataset is:  0.0721
# The value at the other dataset index and feature is:  0.0721
# This_Value is for original dataset is:  0.1021
# The value at the other dataset index and feature is:  0.1021
# This_Value is for original dataset is:  0.0712
# The value at the other dataset index and feature is:  0.0712
# This_Value is for original dataset is:  0.0956
# The value at the other dataset index and feature is:  0.0956
# This_Value is for original dataset is:  0.1632
# The value at the other dataset index and feature is:  0.1632
# This_Value is for original dataset is:  0.2339
# The value at the other dataset index and feature is:  0.2339
# This_Value is for original dataset is:  0.1065
# The value at the other dataset index and feature is:  0.1065
# This_Value is for original dataset is:  0.121
# The value at the other dataset index and feature is:  0.121
# This_Value is for original dataset is:  0.1226
# The value at the other dataset index and feature is:  0.1226
# This_Value is for original dataset is:  0.1163
# The value at the other dataset index and feature is:  0.1163
# This_Value is for original dataset is:  0.107
# The value at the other dataset index and feature is:  0.107
# This_Value is for original dataset is:  0.1278
# The value at the other dataset index and feature is:  0.1278
# This_Value is for original dataset is:  0.1249
# The value at the other dataset index and feature is:  0.1249
# This_Value is for original dataset is:  0.1135
# The value at the other dataset index and feature is:  0.1135
# This_Value is for original dataset is:  0.1252
# The value at the other dataset index and feature is:  0.1252
# This_Value is for original dataset is:  0.1574
# The value at the other dataset index and feature is:  0.1574
# This_Value is for original dataset is:  0.1321
# The value at the other dataset index and feature is:  0.1321
# This_Value is for original dataset is:  0.1636
# The value at the other dataset index and feature is:  0.1636
# This_Value is for original dataset is:  0.3059
# The value at the other dataset index and feature is:  0.3059
# This_Value is for original dataset is:  0.1526
# The value at the other dataset index and feature is:  0.1526
# This_Value is for original dataset is:  0.1268
# The value at the other dataset index and feature is:  0.1268
# This_Value is for original dataset is:  0.1997
# The value at the other dataset index and feature is:  0.1997
# This_Value is for original dataset is:  0.1385
# The value at the other dataset index and feature is:  0.1385
# This_Value is for original dataset is:  0.1665
# The value at the other dataset index and feature is:  0.1665
# This_Value is for original dataset is:  0.1447
# The value at the other dataset index and feature is:  0.1447
# This_Value is for original dataset is:  0.1219
# The value at the other dataset index and feature is:  0.1219
# This_Value is for original dataset is:  0.1276
# The value at the other dataset index and feature is:  0.1276
# This_Value is for original dataset is:  0.1408
# The value at the other dataset index and feature is:  0.1408
# This_Value is for original dataset is:  0.1732
# The value at the other dataset index and feature is:  0.1732
# This_Value is for original dataset is:  0.1252
# The value at the other dataset index and feature is:  0.1252
# This_Value is for original dataset is:  0.1421
# The value at the other dataset index and feature is:  0.1421
# This_Value is for original dataset is:  0.127
# The value at the other dataset index and feature is:  0.127
# This_Value is for original dataset is:  0.4264
# The value at the other dataset index and feature is:  0.4264
# This_Value is for original dataset is:  0.1498
# The value at the other dataset index and feature is:  0.1498
# This_Value is for original dataset is:  0.2604
# The value at the other dataset index and feature is:  0.2604
# This_Value is for original dataset is:  0.1484
# The value at the other dataset index and feature is:  0.1484
# This_Value is for original dataset is:  0.166
# The value at the other dataset index and feature is:  0.166
# This_Value is for original dataset is:  0.1496
# The value at the other dataset index and feature is:  0.1496
# This_Value is for original dataset is:  0.1644
# The value at the other dataset index and feature is:  0.1644
# This_Value is for original dataset is:  0.1497
# The value at the other dataset index and feature is:  0.1497
# This_Value is for original dataset is:  0.2565
# The value at the other dataset index and feature is:  0.2565
# This_Value is for original dataset is:  0.401
# The value at the other dataset index and feature is:  0.401
# This_Value is for original dataset is:  0.3225
# The value at the other dataset index and feature is:  0.3225
# This_Value is for original dataset is:  0.2252
# The value at the other dataset index and feature is:  0.2252
# This_Value is for original dataset is:  0.2482
# The value at the other dataset index and feature is:  0.2482
# This_Value is for original dataset is:  0.2583
# The value at the other dataset index and feature is:  0.2583
# This_Value is for original dataset is:  0.2559
# The value at the other dataset index and feature is:  0.2559
# This_Value is for original dataset is:  0.307
# The value at the other dataset index and feature is:  0.307
# This_Value is for original dataset is:  0.2587
# The value at the other dataset index and feature is:  0.2587
# This_Value is for original dataset is:  0.3823
# The value at the other dataset index and feature is:  0.3823
# This_Value is for original dataset is:  0.2611
# The value at the other dataset index and feature is:  0.2611
# This_Value is for original dataset is:  0.277
# The value at the other dataset index and feature is:  0.277
# This_Value is for original dataset is:  0.2431
# The value at the other dataset index and feature is:  0.2431
# This_Value is for original dataset is:  0.2947
# The value at the other dataset index and feature is:  0.2947
# This_Value is for original dataset is:  0.3008
# The value at the other dataset index and feature is:  0.3008
# This_Value is for original dataset is:  0.3729
# The value at the other dataset index and feature is:  0.3729
# This_Value is for original dataset is:  0.3016
# The value at the other dataset index and feature is:  0.3016
# This_Value is for original dataset is:  0.3322
# The value at the other dataset index and feature is:  0.3322
# This_Value is for original dataset is:  0.3481
# The value at the other dataset index and feature is:  0.3481
# This_Value is for original dataset is:  0.3771
# The value at the other dataset index and feature is:  0.3771
# This_Value is for original dataset is:  0.411
# The value at the other dataset index and feature is:  0.411
# This_Value is for original dataset is:  0.311
# The value at the other dataset index and feature is:  0.311
# This_Value is for original dataset is:  0.3583
# The value at the other dataset index and feature is:  0.3583
# This_Value is for original dataset is:  0.346
# The value at the other dataset index and feature is:  0.346
# This_Value is for original dataset is:  0.4223
# The value at the other dataset index and feature is:  0.4223
# This_Value is for original dataset is:  0.459
# The value at the other dataset index and feature is:  0.459
# This_Value is for original dataset is:  0.4566
# The value at the other dataset index and feature is:  0.4566
# This_Value is for original dataset is:  0.4262
# The value at the other dataset index and feature is:  0.4262
# This_Value is for original dataset is:  0.3465
# The value at the other dataset index and feature is:  0.3465
# This_Value is for original dataset is:  0.5598
# The value at the other dataset index and feature is:  0.5598
# This_Value is for original dataset is:  0.4983
# The value at the other dataset index and feature is:  0.4983
# This_Value is for original dataset is:  0.5744
# The value at the other dataset index and feature is:  0.5744
# This_Value is for original dataset is:  0.5664
# The value at the other dataset index and feature is:  0.5664
# This_Value is for original dataset is:  0.5526
# The value at the other dataset index and feature is:  0.5526
# This_Value is for original dataset is:  0.6587
# The value at the other dataset index and feature is:  0.6587
# This_Value is for original dataset is:  0.6828
# The value at the other dataset index and feature is:  0.6828
# This_Value is for original dataset is:  0.5276
# The value at the other dataset index and feature is:  0.5276
# This_Value is for original dataset is:  0.6194
# The value at the other dataset index and feature is:  0.6194
# This_Value is for original dataset is:  0.592
# The value at the other dataset index and feature is:  0.592
# This_Value is for original dataset is:  0.5378
# The value at the other dataset index and feature is:  0.5378
# This_Value is for original dataset is:  0.6609
# The value at the other dataset index and feature is:  0.6609
# This_Value is for original dataset is:  0.5966
# The value at the other dataset index and feature is:  0.5966
# This_Value is for original dataset is:  0.5079
# The value at the other dataset index and feature is:  0.5079
# This_Value is for original dataset is:  0.5761
# The value at the other dataset index and feature is:  0.5761
# This_Value is for original dataset is:  0.7106
# The value at the other dataset index and feature is:  0.7106
# This_Value is for original dataset is:  0.5965
# The value at the other dataset index and feature is:  0.5965
# This_Value is for original dataset is:  0.5915
# The value at the other dataset index and feature is:  0.5915
# This_Value is for original dataset is:  0.6333
# The value at the other dataset index and feature is:  0.6333
# This_Value is for original dataset is:  0.5832
# The value at the other dataset index and feature is:  0.5832
# This_Value is for original dataset is:  0.7342
# The value at the other dataset index and feature is:  0.7342
# This_Value is for original dataset is:  0.6254
# The value at the other dataset index and feature is:  0.6254
# This_Value is for original dataset is:  0.6675
# The value at the other dataset index and feature is:  0.6675
# This_Value is for original dataset is:  0.6552
# The value at the other dataset index and feature is:  0.6552
# This_Value is for original dataset is:  0.706
# The value at the other dataset index and feature is:  0.706
# This_Value is for original dataset is:  0.6919
# The value at the other dataset index and feature is:  0.6919
# This_Value is for original dataset is:  0.6343
# The value at the other dataset index and feature is:  0.6343
# This_Value is for original dataset is:  0.7022
# The value at the other dataset index and feature is:  0.7022
# This_Value is for original dataset is:  0.7131
# The value at the other dataset index and feature is:  0.7131
# This_Value is for original dataset is:  0.7797
# The value at the other dataset index and feature is:  0.7797
# This_Value is for original dataset is:  0.8198
# The value at the other dataset index and feature is:  0.8198
# This_Value is for original dataset is:  0.7067
# The value at the other dataset index and feature is:  0.7067
# This_Value is for original dataset is:  0.997
# The value at the other dataset index and feature is:  0.997
# This_Value is for original dataset is:  0.7842
# The value at the other dataset index and feature is:  0.7842
# This_Value is for original dataset is:  1.0
# The value at the other dataset index and feature is:  1.0
# This_Value is for original dataset is:  0.9137
# The value at the other dataset index and feature is:  0.9137
# This_Value is for original dataset is:  0.0239
# The value at the other dataset index and feature is:  0.0239
# This_Value is for original dataset is:  0.0248
# The value at the other dataset index and feature is:  0.0248
# This_Value is for original dataset is:  0.8814
# The value at the other dataset index and feature is:  0.8814
# This_Value is for original dataset is:  0.8409
# The value at the other dataset index and feature is:  0.8409
# This_Value is for original dataset is:  1.0
# The value at the other dataset index and feature is:  1.0
# This_Value is for original dataset is:  0.9252
# The value at the other dataset index and feature is:  0.9252
# This_Value is for original dataset is:  0.9016
# The value at the other dataset index and feature is:  0.9016
# This_Value is for original dataset is:  0.9303
# The value at the other dataset index and feature is:  0.9303
# This_Value is for original dataset is:  0.948
# The value at the other dataset index and feature is:  0.948
# This_Value is for original dataset is:  0.9136
# The value at the other dataset index and feature is:  0.9136
# This_Value is for original dataset is:  0.9857
# The value at the other dataset index and feature is:  0.9857
# This_Value is for original dataset is:  0.8753
# The value at the other dataset index and feature is:  0.8753
# This_Value is for original dataset is:  0.9709
# The value at the other dataset index and feature is:  0.9709
# This_Value is for original dataset is:  0.8849
# The value at the other dataset index and feature is:  0.8849
# This_Value is for original dataset is:  0.8827
# The value at the other dataset index and feature is:  0.8827
# This_Value is for original dataset is:  0.9167
# The value at the other dataset index and feature is:  0.9167
# This_Value is for original dataset is:  0.9297
# The value at the other dataset index and feature is:  0.9297
# This_Value is for original dataset is:  0.8979
# The value at the other dataset index and feature is:  0.8979
# This_Value is for original dataset is:  0.8116
# The value at the other dataset index and feature is:  0.8116
# This_Value is for original dataset is:  0.7322
# The value at the other dataset index and feature is:  0.7322
# This_Value is for original dataset is:  0.8995
# The value at the other dataset index and feature is:  0.8995
# This_Value is for original dataset is:  0.7751
# The value at the other dataset index and feature is:  0.7751
# This_Value is for original dataset is:  0.7664
# The value at the other dataset index and feature is:  0.7664
# This_Value is for original dataset is:  0.7911
# The value at the other dataset index and feature is:  0.7911
# This_Value is for original dataset is:  0.7247
# The value at the other dataset index and feature is:  0.7247
# This_Value is for original dataset is:  0.8246
# The value at the other dataset index and feature is:  0.8246
# This_Value is for original dataset is:  0.7988
# The value at the other dataset index and feature is:  0.7988
# This_Value is for original dataset is:  0.7733
# The value at the other dataset index and feature is:  0.7733
# This_Value is for original dataset is:  0.6287
# The value at the other dataset index and feature is:  0.6287
# This_Value is for original dataset is:  0.5826
# The value at the other dataset index and feature is:  0.5826
# This_Value is for original dataset is:  0.7517
# The value at the other dataset index and feature is:  0.7517
# This_Value is for original dataset is:  0.6163
# The value at the other dataset index and feature is:  0.6163
# This_Value is for original dataset is:  0.7762
# The value at the other dataset index and feature is:  0.7762
# This_Value is for original dataset is:  0.5245
# The value at the other dataset index and feature is:  0.5245
# This_Value is for original dataset is:  0.5508
# The value at the other dataset index and feature is:  0.5508
# This_Value is for original dataset is:  0.4921
# The value at the other dataset index and feature is:  0.4921
# This_Value is for original dataset is:  0.5762
# The value at the other dataset index and feature is:  0.5762
# This_Value is for original dataset is:  0.5379
# The value at the other dataset index and feature is:  0.5379
# This_Value is for original dataset is:  0.495
# The value at the other dataset index and feature is:  0.495
# This_Value is for original dataset is:  0.5772
# The value at the other dataset index and feature is:  0.5772
# This_Value is for original dataset is:  0.5663
# The value at the other dataset index and feature is:  0.5663
# This_Value is for original dataset is:  0.4921
# The value at the other dataset index and feature is:  0.4921
# This_Value is for original dataset is:  0.5027
# The value at the other dataset index and feature is:  0.5027
# This_Value is for original dataset is:  0.4407
# The value at the other dataset index and feature is:  0.4407
# This_Value is for original dataset is:  0.6009
# The value at the other dataset index and feature is:  0.6009
# This_Value is for original dataset is:  0.5214
# The value at the other dataset index and feature is:  0.5214
# This_Value is for original dataset is:  0.4693
# The value at the other dataset index and feature is:  0.4693
# This_Value is for original dataset is:  0.4374
# The value at the other dataset index and feature is:  0.4374
# This_Value is for original dataset is:  0.5616
# The value at the other dataset index and feature is:  0.5616
# This_Value is for original dataset is:  0.4894
# The value at the other dataset index and feature is:  0.4894
# This_Value is for original dataset is:  0.5835
# The value at the other dataset index and feature is:  0.5835
# This_Value is for original dataset is:  0.6149
# The value at the other dataset index and feature is:  0.6149
# This_Value is for original dataset is:  0.6448
# The value at the other dataset index and feature is:  0.6448
# This_Value is for original dataset is:  0.576
# The value at the other dataset index and feature is:  0.576
# This_Value is for original dataset is:  0.5858
# The value at the other dataset index and feature is:  0.5858
# This_Value is for original dataset is:  0.5438
# The value at the other dataset index and feature is:  0.5438
# This_Value is for original dataset is:  0.471
# The value at the other dataset index and feature is:  0.471
# This_Value is for original dataset is:  0.5013
# The value at the other dataset index and feature is:  0.5013
# This_Value is for original dataset is:  0.4485
# The value at the other dataset index and feature is:  0.4485
# This_Value is for original dataset is:  0.4373
# The value at the other dataset index and feature is:  0.4373
# This_Value is for original dataset is:  0.5907
# The value at the other dataset index and feature is:  0.5907
# This_Value is for original dataset is:  0.4624
# The value at the other dataset index and feature is:  0.4624
# This_Value is for original dataset is:  0.5749
# The value at the other dataset index and feature is:  0.5749
# This_Value is for original dataset is:  0.5084
# The value at the other dataset index and feature is:  0.5084
# This_Value is for original dataset is:  0.5294
# The value at the other dataset index and feature is:  0.5294
# This_Value is for original dataset is:  0.4892
# The value at the other dataset index and feature is:  0.4892
# This_Value is for original dataset is:  0.7034
# The value at the other dataset index and feature is:  0.7034
# This_Value is for original dataset is:  0.5507
# The value at the other dataset index and feature is:  0.5507
# This_Value is for original dataset is:  0.4514
# The value at the other dataset index and feature is:  0.4514
# This_Value is for original dataset is:  0.4232
# The value at the other dataset index and feature is:  0.4232
# This_Value is for original dataset is:  0.4305
# The value at the other dataset index and feature is:  0.4305
# This_Value is for original dataset is:  0.5777
# The value at the other dataset index and feature is:  0.5777
# This_Value is for original dataset is:  0.5692
# The value at the other dataset index and feature is:  0.5692
# This_Value is for original dataset is:  0.5123
# The value at the other dataset index and feature is:  0.5123
# This_Value is for original dataset is:  0.6214
# The value at the other dataset index and feature is:  0.6214
# This_Value is for original dataset is:  0.5293
# The value at the other dataset index and feature is:  0.5293
# This_Value is for original dataset is:  0.4442
# The value at the other dataset index and feature is:  0.4442
# This_Value is for original dataset is:  0.7292
# The value at the other dataset index and feature is:  0.7292
# This_Value is for original dataset is:  0.5649
# The value at the other dataset index and feature is:  0.5649
# This_Value is for original dataset is:  0.4042
# The value at the other dataset index and feature is:  0.4042
# This_Value is for original dataset is:  0.4803
# The value at the other dataset index and feature is:  0.4803
# This_Value is for original dataset is:  0.4262
# The value at the other dataset index and feature is:  0.4262
# This_Value is for original dataset is:  0.5904
# The value at the other dataset index and feature is:  0.5904
# This_Value is for original dataset is:  0.4331
# The value at the other dataset index and feature is:  0.4331
# This_Value is for original dataset is:  0.3096
# The value at the other dataset index and feature is:  0.3096
# This_Value is for original dataset is:  0.3241
# The value at the other dataset index and feature is:  0.3241
# This_Value is for original dataset is:  0.4315
# The value at the other dataset index and feature is:  0.4315
# This_Value is for original dataset is:  0.3385
# The value at the other dataset index and feature is:  0.3385
# This_Value is for original dataset is:  0.3016
# The value at the other dataset index and feature is:  0.3016
# This_Value is for original dataset is:  0.3287
# The value at the other dataset index and feature is:  0.3287
# This_Value is for original dataset is:  0.5522
# The value at the other dataset index and feature is:  0.5522
# This_Value is for original dataset is:  0.3195
# The value at the other dataset index and feature is:  0.3195
# This_Value is for original dataset is:  0.3123
# The value at the other dataset index and feature is:  0.3123
# This_Value is for original dataset is:  0.3877
# The value at the other dataset index and feature is:  0.3877
# This_Value is for original dataset is:  0.3511
# The value at the other dataset index and feature is:  0.3511
# This_Value is for original dataset is:  0.4069
# The value at the other dataset index and feature is:  0.4069
# This_Value is for original dataset is:  0.2905
# The value at the other dataset index and feature is:  0.2905
# This_Value is for original dataset is:  0.2559
# The value at the other dataset index and feature is:  0.2559
# This_Value is for original dataset is:  0.2945
# The value at the other dataset index and feature is:  0.2945
# This_Value is for original dataset is:  0.264
# The value at the other dataset index and feature is:  0.264
# This_Value is for original dataset is:  0.3339
# The value at the other dataset index and feature is:  0.3339
# This_Value is for original dataset is:  0.2484
# The value at the other dataset index and feature is:  0.2484
# This_Value is for original dataset is:  0.2779
# The value at the other dataset index and feature is:  0.2779
# This_Value is for original dataset is:  0.2458
# The value at the other dataset index and feature is:  0.2458
# This_Value is for original dataset is:  0.2761
# The value at the other dataset index and feature is:  0.2761
# This_Value is for original dataset is:  0.1981
# The value at the other dataset index and feature is:  0.1981
# This_Value is for original dataset is:  0.1366
# The value at the other dataset index and feature is:  0.1366
# This_Value is for original dataset is:  0.1326
# The value at the other dataset index and feature is:  0.1326
# This_Value is for original dataset is:  0.1474
# The value at the other dataset index and feature is:  0.1474
# This_Value is for original dataset is:  0.1794
# The value at the other dataset index and feature is:  0.1794
# This_Value is for original dataset is:  0.1608
# The value at the other dataset index and feature is:  0.1608
# This_Value is for original dataset is:  0.1427
# The value at the other dataset index and feature is:  0.1427
# This_Value is for original dataset is:  0.1584
# The value at the other dataset index and feature is:  0.1584
# This_Value is for original dataset is:  0.0469
# The value at the other dataset index and feature is:  0.0469
# This_Value is for original dataset is:  0.0779
# The value at the other dataset index and feature is:  0.0779
# This_Value is for original dataset is:  0.0637
# The value at the other dataset index and feature is:  0.0637
# This_Value is for original dataset is:  0.0473
# The value at the other dataset index and feature is:  0.0473
# This_Value is for original dataset is:  0.0507
# The value at the other dataset index and feature is:  0.0507
# This_Value is for original dataset is:  0.0499
# The value at the other dataset index and feature is:  0.0499
# This_Value is for original dataset is:  0.0469
# The value at the other dataset index and feature is:  0.0469
# This_Value is for original dataset is:  0.0772
# The value at the other dataset index and feature is:  0.0772
# This_Value is for original dataset is:  0.0628
# The value at the other dataset index and feature is:  0.0628
# This_Value is for original dataset is:  0.0475
# The value at the other dataset index and feature is:  0.0475
# This_Value is for original dataset is:  0.0825
# The value at the other dataset index and feature is:  0.0825
# This_Value is for original dataset is:  0.0462
# The value at the other dataset index and feature is:  0.0462
# This_Value is for original dataset is:  0.0493
# The value at the other dataset index and feature is:  0.0493
# This_Value is for original dataset is:  0.051
# The value at the other dataset index and feature is:  0.051
# This_Value is for original dataset is:  0.0426
# The value at the other dataset index and feature is:  0.0426
# This_Value is for original dataset is:  0.0396
# The value at the other dataset index and feature is:  0.0396
# This_Value is for original dataset is:  0.048
# The value at the other dataset index and feature is:  0.048
# This_Value is for original dataset is:  0.0798
# The value at the other dataset index and feature is:  0.0798
# This_Value is for original dataset is:  0.0456
# The value at the other dataset index and feature is:  0.0456
# This_Value is for original dataset is:  0.1004
# The value at the other dataset index and feature is:  0.1004
# This_Value is for original dataset is:  0.0346
# The value at the other dataset index and feature is:  0.0346
# This_Value is for original dataset is:  0.0331
# The value at the other dataset index and feature is:  0.0331
# This_Value is for original dataset is:  0.0386
# The value at the other dataset index and feature is:  0.0386
# This_Value is for original dataset is:  0.0362
# The value at the other dataset index and feature is:  0.0362
# This_Value is for original dataset is:  0.0331
# The value at the other dataset index and feature is:  0.0331
# This_Value is for original dataset is:  0.0321
# The value at the other dataset index and feature is:  0.0321
# This_Value is for original dataset is:  0.0455
# The value at the other dataset index and feature is:  0.0455
# This_Value is for original dataset is:  0.0444
# The value at the other dataset index and feature is:  0.0444
# This_Value is for original dataset is:  0.0376
# The value at the other dataset index and feature is:  0.0376
# This_Value is for original dataset is:  0.0339
# The value at the other dataset index and feature is:  0.0339
# This_Value is for original dataset is:  0.0432
# The value at the other dataset index and feature is:  0.0432
# This_Value is for original dataset is:  0.0459
# The value at the other dataset index and feature is:  0.0459
# This_Value is for original dataset is:  0.0709
# The value at the other dataset index and feature is:  0.0709
# This_Value is for original dataset is:  0.039
# The value at the other dataset index and feature is:  0.039
# This_Value is for original dataset is:  0.0317
# The value at the other dataset index and feature is:  0.0317
# This_Value is for original dataset is:  0.0361
# The value at the other dataset index and feature is:  0.0361
# This_Value is for original dataset is:  0.0344
# The value at the other dataset index and feature is:  0.0344
# This_Value is for original dataset is:  0.0303
# The value at the other dataset index and feature is:  0.0303
# This_Value is for original dataset is:  0.0294
# The value at the other dataset index and feature is:  0.0294
# This_Value is for original dataset is:  0.0352
# The value at the other dataset index and feature is:  0.0352
# This_Value is for original dataset is:  0.029
# The value at the other dataset index and feature is:  0.029
# This_Value is for original dataset is:  0.0335
# The value at the other dataset index and feature is:  0.0335
# This_Value is for original dataset is:  0.0309
# The value at the other dataset index and feature is:  0.0309
# This_Value is for original dataset is:  0.029
# The value at the other dataset index and feature is:  0.029
# This_Value is for original dataset is:  0.0277
# The value at the other dataset index and feature is:  0.0277
# This_Value is for original dataset is:  0.027
# The value at the other dataset index and feature is:  0.027
# This_Value is for original dataset is:  0.0372
# The value at the other dataset index and feature is:  0.0372
# This_Value is for original dataset is:  0.0276
# The value at the other dataset index and feature is:  0.0276
# This_Value is for original dataset is:  0.0376
# The value at the other dataset index and feature is:  0.0376
# This_Value is for original dataset is:  0.0281
# The value at the other dataset index and feature is:  0.0281
# This_Value is for original dataset is:  0.0252
# The value at the other dataset index and feature is:  0.0252
# This_Value is for original dataset is:  0.0447
# The value at the other dataset index and feature is:  0.0447
# This_Value is for original dataset is:  0.0244
# The value at the other dataset index and feature is:  0.0244
# This_Value is for original dataset is:  0.0277
# The value at the other dataset index and feature is:  0.0277
# This_Value is for original dataset is:  0.0212
# The value at the other dataset index and feature is:  0.0212
# This_Value is for original dataset is:  0.0249
# The value at the other dataset index and feature is:  0.0249
# This_Value is for original dataset is:  0.0326
# The value at the other dataset index and feature is:  0.0326
# This_Value is for original dataset is:  0.0394
# The value at the other dataset index and feature is:  0.0394
# This_Value is for original dataset is:  0.0316
# The value at the other dataset index and feature is:  0.0316
# This_Value is for original dataset is:  0.0229
# The value at the other dataset index and feature is:  0.0229
# This_Value is for original dataset is:  0.0217
# The value at the other dataset index and feature is:  0.0217
# This_Value is for original dataset is:  0.0258
# The value at the other dataset index and feature is:  0.0258
# This_Value is for original dataset is:  0.0242
# The value at the other dataset index and feature is:  0.0242
# This_Value is for original dataset is:  0.023
# The value at the other dataset index and feature is:  0.023
# This_Value is for original dataset is:  0.0218
# The value at the other dataset index and feature is:  0.0218
# This_Value is for original dataset is:  0.0355
# The value at the other dataset index and feature is:  0.0355
# This_Value is for original dataset is:  0.0224
# The value at the other dataset index and feature is:  0.0224
# This_Value is for original dataset is:  0.0377
# The value at the other dataset index and feature is:  0.0377
# This_Value is for original dataset is:  0.0321
# The value at the other dataset index and feature is:  0.0321
# This_Value is for original dataset is:  0.0244
# The value at the other dataset index and feature is:  0.0244
# This_Value is for original dataset is:  0.0288
# The value at the other dataset index and feature is:  0.0288
# This_Value is for original dataset is:  0.0205
# The value at the other dataset index and feature is:  0.0205
# This_Value is for original dataset is:  0.0225
# The value at the other dataset index and feature is:  0.0225
# This_Value is for original dataset is:  0.0214
# The value at the other dataset index and feature is:  0.0214
# This_Value is for original dataset is:  0.044
# The value at the other dataset index and feature is:  0.044
# This_Value is for original dataset is:  0.0255
# The value at the other dataset index and feature is:  0.0255
# This_Value is for original dataset is:  0.0294
# The value at the other dataset index and feature is:  0.0294
# This_Value is for original dataset is:  0.022
# The value at the other dataset index and feature is:  0.022
# This_Value is for original dataset is:  0.0332
# The value at the other dataset index and feature is:  0.0332
# This_Value is for original dataset is:  0.0228
# The value at the other dataset index and feature is:  0.0228
# This_Value is for original dataset is:  0.0246
# The value at the other dataset index and feature is:  0.0246
# This_Value is for original dataset is:  0.021
# The value at the other dataset index and feature is:  0.021
# This_Value is for original dataset is:  0.0245
# The value at the other dataset index and feature is:  0.0245
# This_Value is for original dataset is:  0.0207
# The value at the other dataset index and feature is:  0.0207
# This_Value is for original dataset is:  0.0364
# The value at the other dataset index and feature is:  0.0364
# This_Value is for original dataset is:  0.0227
# The value at the other dataset index and feature is:  0.0227
# This_Value is for original dataset is:  0.0243
# The value at the other dataset index and feature is:  0.0243
# This_Value is for original dataset is:  0.018
# The value at the other dataset index and feature is:  0.018
# This_Value is for original dataset is:  0.0173
# The value at the other dataset index and feature is:  0.0173
# This_Value is for original dataset is:  0.0439
# The value at the other dataset index and feature is:  0.0439
# This_Value is for original dataset is:  0.0231
# The value at the other dataset index and feature is:  0.0231
# This_Value is for original dataset is:  0.0198
# The value at the other dataset index and feature is:  0.0198
# This_Value is for original dataset is:  0.0187
# The value at the other dataset index and feature is:  0.0187
# This_Value is for original dataset is:  0.0218
# The value at the other dataset index and feature is:  0.0218
# This_Value is for original dataset is:  0.0208
# The value at the other dataset index and feature is:  0.0208

# %%
#Checking dataset again to see if any NaN's can be seen
dataset_no_outliers
# Out:
#          V0      V1      V2      V3      V4      V5      V6      V7      V8  \
# 0    0.0200  0.0371  0.0428  0.0207  0.0954  0.0986  0.1539  0.1601  0.3109
# 1    0.0453  0.0523  0.0843  0.0689  0.1183     NaN  0.2156     NaN  0.3337
# 2    0.0262  0.0582  0.1099  0.1083  0.0974  0.2280  0.2431     NaN     NaN
# 3    0.0100  0.0171  0.0623  0.0205  0.0205  0.0368  0.1098  0.1276  0.0598
# 4       NaN  0.0666  0.0481  0.0394  0.0590  0.0649  0.1209  0.2467  0.3564
# ..      ...     ...     ...     ...     ...     ...     ...     ...     ...
# 203  0.0187  0.0346  0.0168  0.0177  0.0393  0.1630  0.2028  0.1694  0.2328
# 204  0.0323  0.0101  0.0298  0.0564  0.0760  0.0958  0.0990  0.1018  0.1030
# 205  0.0522  0.0437  0.0180  0.0292  0.0351  0.1171  0.1257  0.1178  0.1258
# 206  0.0303  0.0353  0.0490  0.0608  0.0167  0.1354  0.1465  0.1123  0.1945
# 207  0.0260  0.0363  0.0136  0.0272  0.0214  0.0338  0.0655  0.1400  0.1843
#
#          V9  ...     V51     V52     V53     V54     V55     V56     V57  \
# 0    0.2111  ...  0.0027  0.0065  0.0159  0.0072  0.0167  0.0180  0.0084
# 1    0.2872  ...  0.0084  0.0089  0.0048  0.0094  0.0191  0.0140  0.0049
# 2       NaN  ...  0.0232  0.0166  0.0095  0.0180     NaN     NaN  0.0164
# 3    0.1264  ...  0.0121  0.0036  0.0150  0.0085  0.0073  0.0050  0.0044
# 4    0.4459  ...  0.0031  0.0054  0.0105  0.0110  0.0015  0.0072  0.0048
# ..      ...  ...     ...     ...     ...     ...     ...     ...     ...
# 203  0.2684  ...  0.0116  0.0098  0.0199  0.0033  0.0101  0.0065  0.0115
# 204  0.2154  ...  0.0061  0.0093  0.0135  0.0063  0.0063  0.0034  0.0032
# 205  0.2529  ...  0.0160  0.0029  0.0051  0.0062  0.0089  0.0140  0.0138
# 206  0.2354  ...  0.0086  0.0046  0.0126  0.0036  0.0035  0.0034  0.0079
# 207  0.2354  ...  0.0146  0.0129  0.0047  0.0039  0.0061  0.0040  0.0036
#
#         V58     V59  V60
# 0    0.0090  0.0032    R
# 1    0.0052  0.0044    R
# 2    0.0095  0.0078    R
# 3    0.0040  0.0117    R
# 4    0.0107  0.0094    R
# ..      ...     ...  ...
# 203  0.0193  0.0157    M
# 204  0.0062  0.0067    M
# 205  0.0077  0.0031    M
# 206  0.0036  0.0048    M
# 207  0.0061  0.0115    M
#
# [208 rows x 61 columns]

# %%
#Calculated the percentage of outliers last row, need an array of them to do more now
#X is the number of rows that has specifically this many outliers
#Y is the the total percentage of rows that have this many outliers
# dataset_no_outliers.size #There are a total of 12,480 cells in this dataframe

outlier_array = []

for index, row in dataset_no_outliers.iterrows():
  
  number_of_outliers = 0

  for value in row:
    if( pd.isna(value)):
      
      number_of_outliers += 1
      # print(number_of_outliers)
    
  
  # outlier_by_Row.append(pd.Series([number_of_outliers]))
  outlier_array.append(number_of_outliers)
  # print(number_of_outliers)

outlier_by_Row = pd.Series(outlier_array)

outlier_by_Row
# Out:
# 0      0
# 1      5
# 2      7
# 3      3
# 4      1
#       ..
# 203    0
# 204    0
# 205    0
# 206    0
# 207    0
# Length: 208, dtype: int64

# %%
#calculate the percentage of the same values are the total 
fig, ax1 = plt.subplots(figsize=(15,10))

#x and y labels for the histogram
ax1.set_xlabel("Number Of Outliers")
ax1.set_ylabel("% Of Rows")

#placing a bar graph with sorted  axis
Percentage_by_number_of_rows = outlier_by_Row.value_counts(normalize=True)
sorted_by_index = Percentage_by_number_of_rows.sort_index()
sorted_by_index.plot.bar(ylim=(0,0.7))
# Out:
# <AxesSubplot:xlabel='Number Of Outliers', ylabel='% Of Rows'>

# %% [markdown]
# # 2. A more flexible notion of outliers
# ## 2.1 Graphical approach: quantile-quantile (QQ) plot
#
# A __very important shortcoming__ of either method in section 1 is that they take a very rigid definition of outliers where having long tails is bad no matter what. However, not all data is supposed to be distributed around a mean 'representative' values. Sometimes the data is distributed according to very skewed distributions, and that's what it's supposed to be: ignoring the tail of the distribution would actually make an erroneous assumption of normalcy. So we need a more flexible notion of what it means to be an outlier.
#
# An outlier means that some values significantly derive from what would be obtained by an _assumed distribution_. Which distribution to assume depends on what we know about the problem. Sometimes, we expect a normal distribution (e.g., distribution of height). Sometimes, we expect a heavy tail distribution (e.g., distribution of incomes).
#
# A __Q–Q__ plot is a plot of the quantiles of two distributions against each other. The pattern of points in the plot is used to compare the two distributions. When your sample matches the expected distribution, you see points on the diagonal. When points deviate from the diagonal, it means that it doesn't match. This example from Wikipedia shows that a dataset follows a Weibull distribution (i.e. most points fall on the diagonal), with the exception of three outliers:
# <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/c/ca/Weibull_qq.svg/360px-Weibull_qq.svg.png">
# (If you want to know more, you can read the Wikipedia entry on [Q-Q plot](https://en.wikipedia.org/wiki/Q%E2%80%93Q_plot).)
#
# Here is the code to perform a Q-Q plot on column V0, by comparison with a normal distribution.

# %%
import numpy as np
import scipy.stats as stats #full of great statistical functions!
import pylab
stats.probplot(dataset["V0"], dist="norm",plot=pylab); #the final ; hides the numbers
#the 'dist' can be any continuous distribution listed here:
#https://docs.scipy.org/doc/scipy/reference/stats.html

# %% [markdown]
# > ___Milestone 4___
# >
# > The normal distribution doesn't fit well with our data, as exemplified above on attribute V0. <font color='red'>Pick any attribute you want, and show which distribution would fit it better than a normal</font>. If you're looking for heavy-tailed distributions, you can find a list [here](https://en.wikipedia.org/wiki/Heavy-tailed_distribution#Common_heavy-tailed_distributions). If you're looking for what scipy.stats gives you access to, you'll find it under continuous distributions [here](https://docs.scipy.org/doc/scipy/reference/stats.html).
# >
# > Please note that <b>not every single distribution will work</b>. Some will just crash because they cannot be used a distribution arguments in a probplot. Don't worry about the ones that crash (they're more complicated to use): simply look through the various options, note the ones that don't crash, and see what the result looks like.
#
# ---
# ---
# Tremendous code starts below.

# %%
#Need to find a distribution that fits V0 better than a normal distribution
#Values are in approximate shape y=x^2
#A tailed distribution will be closest based on that approximation
#This obviously means an exponential, shortened to expon distribution will be much closer, especially if we fit it.
import numpy as np
import matplotlib as plt

stats.probplot(dataset["V0"], dist="expon", fit= True,plot=pylab);

#Can tell it's a soft exponent but stull fits better

# %% [markdown]
# ## 2.2 Statitical approach: fitting distributions
#
# Similarly to section 1, you can realize that the 'visual' approach of the Q-Q plot can be great communication tool but is a poor idea to automatically find outliers in large datasets. You simply can't keep on typing code to generate different distributions, and visually compare. A more scalable and systematic approach is to __fit curves__. That is, you give Python the equation of a curve (such as the line y=ax+b), and it'll give you the best parameter values (a, b) given your data. If the best fit is still poor, then the curve you thought of wasn't good for that data. If it's a good fit, you can use it for the data, and loop to find points that deviate from it. The code below prepares one feature (V0) for curve fitting, then tries to fit the best possible curve, and displays it. As you'll see, it's a bad fit, because the distribution really doesn't follow a line.

# %%
#----PREPARE DATA FOR CURVE FITTING
import numpy as np
Y,X = np.histogram(dataset['V0'], bins=100) # we fit the DISTRIBUTION of the data
X = X[:-1] + (X[1] - X[0])/2   # convert bin edges to centers

#----FIT THE BEST LINE
from scipy.optimize import curve_fit
def line(x, a, b):
    return a * x + b

popt, pcov = curve_fit(line, X, Y)
popt #values of a and b, that is, the slope and offset

# %%
#compare our fitted line to the data
res=[line(val, popt[0], popt[1]) for val in X] #use our fitted line to compute predictions

import matplotlib.pyplot as plt
# %matplotlib inline
plt.plot(X, Y, 'bo', label = 'Original')
plt.plot(X, res, 'r-', label = 'Fit')
plt.show()

# %% [markdown]
# > ___Milestone 5___
# >
# > <font color='red'>Write the code (inspired by the example above) to fit a __good__ curve over feature V0.</font> If you have statistical knowledge, you may look at the distribution, note that it's skewed and figure out the type of distributions that are good 'candidates' for this situation. If you are a bit light on statistics, remember that Milestone 4 had several pointers towards lists of distributions: you can pick some of them, go on Wikipedia to get their equations, and then write them as a function (just like ```def line```).
# >
# > Please note that curve fitting does have its limits. If you're trying to find the best fit for a function with two arguments, a curve fitting is essentially a 'somewhat sophisticated way' of doing a grid search (=nested loop) for you. Sometimes it guesses well, and sometimes not so much. If you think your function is the right one but the curve fitting simply cannot seem to handle it, you can write a nested loop yourself. The criteria in the nested loop (i.e. the quantity that the grid search seeks to optimize) is the [goodness-of-fit](https://en.wikipedia.org/wiki/Goodness_of_fit).
#
# Supercalifragilisticexpialidocious code starts there:
#
# ---
# ---

# %%
#Best line to my eyes is roughly 1/X, though with a different power of 10
#Write up a few points from that as lowercase x y


x=[0.001,0.02,0.04,0.06,0.08,0.10,0.12,0.14]
y=[0.01/x for x in x]
print(y)
print(x)

plt.xticks(ticks=x, labels=x)
plt.plot(X, res, 'r-', label = 'Fit')
plt.plot(X, Y, 'bo', label = 'Original')
plt.plot(y, 'g')


plt.show()

#Not sure why it's displaying a bunch of data that I'm not giving it for the green line
# Out:
# [10.0, 0.5, 0.25, 0.16666666666666669, 0.125, 0.09999999999999999, 0.08333333333333334, 0.07142857142857142]
# [0.001, 0.02, 0.04, 0.06, 0.08, 0.1, 0.12, 0.14]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-773320672d29> in <module>
#       9
#      10 plt.xticks(ticks=x, labels=x)
# ---> 11 plt.plot(X, res, 'r-', label = 'Fit')
#      12 plt.plot(X, Y, 'bo', label = 'Original')
#      13 plt.plot(y, 'g')
#
# NameError: name 'X' is not defined

# %% [markdown]
# # 2.3 Empirical distributions
# To fit the best curve, you'd need to loop over all 'legit' continuous distributions. There aren't too many, so you certainly can code it. But it's computationally expensive, and your data may just not fit anything too well. For instance, it could be a [mixture distribution](https://en.wikipedia.org/wiki/Mixture_distribution) because it's produced by several distributions together, hence it doesn't look like any __one__ perfectly. The alternative to fitting standard distributions is to use your empirical distributions, that is, turn your distribution into a curve. This code shows you the distribution for our favorite feature V0:

# %%
dataset["V0"].plot(kind="hist", bins=100)

# %% [markdown]
# You need to go from the (partial) histogram of your data to the continuous distribution that the (full) data should have. If you don't want to make an assumption on the shape of that distribution, you can __smooth your histogram via a [spline](https://en.wikipedia.org/wiki/Spline_interpolation)__. This code does it:

# %%
def spline(myData, smoothing=2):
    from scipy.interpolate import UnivariateSpline
    N = len(myData)
    n = int(N/10)
    s = myData
    p, x = np.histogram(s, bins=n) # bin it into n = N/10 bins
    x = x[:-1] + (x[1] - x[0])/2   # convert bin edges to centers
    f = UnivariateSpline(x, p, s=smoothing)
    
    plt.plot(x, p, 'bo', label = 'Original')
    plt.plot(x, f(x), 'r', label = 'Interpolated')
    plt.show()
    return f

spline(dataset["V0"], smoothing=300)
#you can save the result in a variable, and apply .get_coeffs() or .get_knots()
#to have the characteristics of the spline

# %% [markdown]
# > ___Milestone 6___
# >
# > Read the documentation for scipy.interpolate and UnivariateSpline. Then, experiment with different values of smoothing (set to 300 in the example above). Finally, <font color="red">write in plain English what smoothing is, and how it's affected by the value</font>.
#
# ---
# ---
#
# Your crystal clear explanation starts here!

# %% [markdown]
# <font color="grey">Explanations...</font>
#     I already knew what splining was in reference to the measuring technique for carpentry/construction thanks to an old job. Saying "Splining is the mathmatical technique of measuring a curve based on predefined point in a similar way to the carpentry technique" makes perfect sense to me. The mathmatical equation's complexity depends on the number of spline points, but is generally built on weighted series of Xsubscripts

# %% [markdown]
# # 3. Outlier handling
#
# The previous sections showed you increasingly sophisticated approaches to detect outliers. You have mostly three ways of dealing with them:
# * __Removing__ all records that contain them. The code would consist of what you did in the 2nd task (to find outliers), then transform the values in N/A, and use Panda's dropna(). The issue with this approach is that you could end up removing a lot of your data, so realistically you have to presence as much data as you can.
# * __Replacing__ outliers by a plausible value (known as 'imputation'). To find a plausible value, you'd need to figure out which distribution is most likely to produce the data. Then, you can remove the erroneous point, and randomly generate one based on the 'right' distribution instead.
# * Don't deal with them in the data. Leave them there. But choose __robust machine learning methods__ with built-in approaches to tolerate outliers or missing data points. For instance, if you do a regression, you can't just fit a line as usual. You would need to use a more robust method, [such as Theil-Sen](https://en.wikipedia.org/wiki/Theil%E2%80%93Sen_estimator).
#
# Note that all three solutions above can __also be used when you have missing data__, instead of incorrect data.

# %% [markdown]
# > ___Milestone 7___
# >
# > Use the removal method to identify outlier values and discard entries that have them. That is, if a row contains at least one outlier value, that row should be removed.
#
# Somewhat painful but liberating code starts, and ends, here.
#
# ---
# ---

# %%
#Can reuse the code from earlier problem, just have it get rid of the outlier instead of just adding it to a list
#and calculating the percentage of outliers
df=pd.DataFrame(dataset, columns=['V0','V1','V2','V3','V4','V5','V6','V7','V8','V9','V10','V11','V12'])
df1=df.describe()
df1

# %%
i=0
columns=['V0','V1','V2','V3','V4','V5','V6','V7','V8','V9','V10','V11','V12']
while(i<12):
    #translates to 75%-25%
    IQR=df1.iloc[6,i]-df1.iloc[4,i]
    #25%-1.5*IQR per formula
    min_lim= df1.iloc[4,i] - 1.5 * IQR 
    #75%-1.5*IQR per formula
    max_lim= df1.iloc[6,i] + 1.5 * IQR 
    outlier =[] 
    for x in df[columns[i]]:
        if (x> max_lim) or (x<min_lim):
            df.truncate(x)
    percentageOut=(len(outlier)/208)*100
    print('outlier percentage on column', i+1,':')
    print(percentageOut)
    outlier.clear()
    i=i+1
df1.describe()
#Can tell by the different values in the cells of df1.description that the truncation worked
